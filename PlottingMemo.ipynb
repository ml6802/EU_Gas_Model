# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.patches import Patch
import plotly
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
Base0drdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2Base0DR.csv")
Basemiddrdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2BaseMidDR.csv")
Basehighdrdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2BaseHighDR.csv")
NW0drdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2NW0DR.csv")
NWmiddrdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2NWMidDR.csv")
NWhighdrdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2NWHighDR.csv")

fig = plt.figure(1, figsize=(20, 10))
ax1 = plt.subplot(2,3,1)
Base0drdf.plot(ax=plt.gca()) #no need to specify for first axis
ax2 = plt.subplot(2,3,2)
Basemiddrdf.plot(ax=plt.gca())
ax3 = plt.subplot(2,3,3)
Basehighdrdf.plot(ax=plt.gca())
ax4 = plt.subplot(2,3,4)
NW0drdf.plot(ax=plt.gca()) #no need to specify for first axis
ax5 = plt.subplot(2,3,5)
NWmiddrdf.plot(ax=plt.gca())
ax6 = plt.subplot(2,3,6)
NWhighdrdf.plot(ax=plt.gca())

ax1.set_title('Zero Demand Reduction', fontdict = {'fontsize':20})
ax2.set_title('Moderate Demand Reduction', fontdict = {'fontsize':20})
ax3.set_title('High Demand Reduction', fontdict = {'fontsize':20})
ax1.set_ylabel('Base           ', rotation=0, fontsize=20)
ax4.set_ylabel('Less Winter Gas                      ', rotation=0, fontsize=20)
fig.tight_layout()
plt.show()
plt.savefig('NoShortfall.png', bbox_inches='tight', dpi = 150)

# %%
Base0drdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2Zero.csv")
Basebasedrdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2BaseDR.csv")
Basemoddrdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2ModDR.csv")
Basedeepdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2DeepDR.csv")
EUzerodf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2EUstorZero.csv")
EUbasedf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2EUstorBase.csv")
EUmoddf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2EUstorMod.csv")
EUdeepdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2EUstorDeep.csv")

labels = np.arange(4,28,1)
fig = plt.figure(2, figsize=(25, 10))
gs = fig.add_gridspec(2, 4, hspace=0.05, wspace=0.1)
(ax1, ax2, ax3, ax4),(ax5, ax6, ax7, ax8) = gs.subplots(sharex='col', sharey='row')
ax1.plot(labels, Base0drdf['Shortfall'].to_list(), linewidth = 3, color = 'tab:red')
ax1.plot(labels, Base0drdf['Storage'].to_list(), linewidth = 3, color = 'tab:orange')
ax1.plot(labels, Base0drdf['LNG'].to_list(), linewidth = 3, color = 'purple')
ax1.plot(labels, Base0drdf['Demand'].to_list(), linewidth = 3, color = 'blue')
ax2.plot(labels, Basebasedrdf['Shortfall'].to_list(), linewidth = 3, color = 'tab:red')
ax2.plot(labels, Basebasedrdf['Storage'].to_list(), linewidth = 3, color = 'tab:orange')
ax2.plot(labels, Basebasedrdf['LNG'].to_list(), linewidth = 3, color = 'purple')
ax2.plot(labels, Basebasedrdf['Demand'].to_list(), linewidth = 3, color = 'blue')
ax3.plot(labels, Basemoddrdf['Shortfall'].to_list(), linewidth = 3, color = 'tab:red')
ax3.plot(labels, Basemoddrdf['Storage'].to_list(), linewidth = 3, color = 'tab:orange')
ax3.plot(labels, Basemoddrdf['LNG'].to_list(), linewidth = 3, color = 'purple')
ax3.plot(labels, Basemoddrdf['Demand'].to_list(), linewidth = 3, color = 'blue')
ax4.plot(labels, Basedeepdf['Shortfall'].to_list(), linewidth = 3, color = 'tab:red')
ax4.plot(labels, Basedeepdf['Storage'].to_list(), linewidth = 3, color = 'tab:orange')
ax4.plot(labels, Basedeepdf['LNG'].to_list(), linewidth = 3, color = 'purple')
ax4.plot(labels, Basedeepdf['Demand'].to_list(), linewidth = 3, color = 'blue')
ax5.plot(labels, EUzerodf['Shortfall'].to_list(), linewidth = 3, color = 'tab:red',label='Shortfall')
ax5.plot(labels, EUzerodf['Storage'].to_list(), linewidth = 3, color = 'tab:orange',label='Storage')
ax5.plot(labels, EUzerodf['LNG'].to_list(), linewidth = 3, color = 'purple',label='LNG Imports')
ax5.plot(labels, EUzerodf['Demand'].to_list(), linewidth = 3, color = 'blue',label='Demand')
ax6.plot(labels, EUbasedf['Shortfall'].to_list(), linewidth = 3, color = 'tab:red')
ax6.plot(labels, EUbasedf['Storage'].to_list(), linewidth = 3, color = 'tab:orange')
ax6.plot(labels, EUbasedf['LNG'].to_list(), linewidth = 3, color = 'purple')
ax6.plot(labels, EUbasedf['Demand'].to_list(), linewidth = 3, color = 'blue')
ax7.plot(labels, EUmoddf['Shortfall'].to_list(), linewidth = 3, color = 'tab:red')
ax7.plot(labels, EUmoddf['Storage'].to_list(), linewidth = 3, color = 'tab:orange')
ax7.plot(labels, EUmoddf['LNG'].to_list(), linewidth = 3, color = 'purple')
ax7.plot(labels, EUmoddf['Demand'].to_list(), linewidth = 3, color = 'blue')
ax8.plot(labels, EUdeepdf['Shortfall'].to_list(), linewidth = 3, color = 'tab:red')
ax8.plot(labels, EUdeepdf['Storage'].to_list(), linewidth = 3, color = 'tab:orange')
ax8.plot(labels, EUdeepdf['LNG'].to_list(), linewidth = 3, color = 'purple')
ax8.plot(labels, EUdeepdf['Demand'].to_list(), linewidth = 3, color = 'blue')

ax1.set_title('Minimial Scenario,\n70 BCM Gas Electricity Reduction', fontdict = {'fontsize':20})
ax2.set_title('Baseline Demand Reduction,\n70 BCM Fuel Switching', fontdict = {'fontsize':20})
ax3.set_title('Moderate Demand Reduction,\n60 BCM Fuel Switching', fontdict = {'fontsize':20})
ax4.set_title('Deep Demand Reduction,\n50 BCM Fuel Switching', fontdict = {'fontsize':20})
ax1.set_ylabel('Scaled Storage                         \nRequirement                        ', rotation=0, fontsize=20)
ax5.set_ylabel('90% Storage                      \nRequirement                      ', rotation=0, fontsize=20)
ax6.set_xlabel('                                                         Months', fontsize = 20)
ax5.legend(loc='lower left',bbox_to_anchor=(1, -0.35), fontsize=20, ncol=4)
plt.savefig('WZeroShortfall.png', bbox_inches='tight', dpi = 150)
plt.show()

# %%
Basebasedrdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2BaseDR.csv")
Basemoddrdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2ModDR.csv")
Basedeepdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2DeepDR.csv")
EUbasedf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2EUstorBase.csv")
EUmoddf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2EUstorMod.csv")
EUdeepdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot2EUstorDeep.csv")

labels = ["4/22", "5/22","6/22","7/22","8/22","9/22","10/22","11/22","12/22", "1/23","2/23","3/23","4/23","5/23","6/23","7/23","8/23","9/23","10/23","11/23","12/23","1/24","2/24", "3/24"]
fig = plt.figure(2, figsize=(20, 8))
gs = fig.add_gridspec(1, 2, hspace=0.05, wspace=0.1)
(ax1, ax2) = gs.subplots(sharex='col', sharey='row')
ax1.plot(labels, Basemoddrdf['Shortfall'].to_list(), linewidth = 3, color = 'tab:red')
ax1.plot(labels, Basemoddrdf['Storage'].to_list(), linewidth = 3, color = 'tab:orange')
ax1.plot(labels, Basemoddrdf['LNG'].to_list(), linewidth = 3, color = 'purple')
ax1.plot(labels, Basemoddrdf['Demand'].to_list(), linewidth = 3, color = 'blue')
ax2.plot(labels, EUmoddf['Shortfall'].to_list(), linewidth = 3, color = 'tab:red',label='Shortfall')
ax2.plot(labels, EUmoddf['Storage'].to_list(), linewidth = 3, color = 'tab:orange',label='Storage')
ax2.plot(labels, EUmoddf['LNG'].to_list(), linewidth = 3, color = 'purple',label='LNG Imports')
ax2.plot(labels, EUmoddf['Demand'].to_list(), linewidth = 3, color = 'blue',label='Demand')

ax1.set_title('Scaled Storage Requirement', fontdict = {'fontsize':20})
ax2.set_title('EU Storage Requirement', fontdict = {'fontsize':20})
ax1.set_ylabel('bcm', fontsize=16)
ax1.set_ylim([0, 95])
ax2.set_ylim([0, 95])
for label in (ax1.get_yticklabels()):
    label.set_fontsize(16)
ax1.set_ylabel('bcm', fontsize=18)
ax1.set_xlabel('Months', fontsize = 20)
ax2.set_xlabel('Months', fontsize = 20)
n = 6  # Keeps every 4th label
for index, label in enumerate(ax1.xaxis.get_ticklabels()):
    label.set_fontsize(16)
    if index % n != 0 and index != 23:
        label.set_visible(False)
for index, label in enumerate(ax2.xaxis.get_ticklabels()):
    label.set_fontsize(16)
    if index % n != 0 and index != 23:
        label.set_visible(False)
ax2.legend(loc='lower center',bbox_to_anchor=(-0.06, -0.22), fontsize=20, ncol=4)
plt.savefig('NoZeroShortfall.png', bbox_inches='tight', dpi = 150)
plt.show()

# %%
Em_coaldf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsCoalComb.csv", header = 'infer', sep = ',')
Em_oildf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsOilComb.csv", header = 'infer', sep = ',')
Em_NGcombdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsNGComb.csv", header = 'infer', sep = ',')
Em_NGUpdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsNGUpstream.csv", header = 'infer', sep = ',')
sfbasedf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot1ShortfallBase.csv", header = 'infer', sep = ',')
em_tot = Em_NGcombdf + Em_NGUpdf + Em_coaldf + Em_oildf
em_tot_dom = Em_NGcombdf + Em_coaldf + Em_oildf
em_co_o = Em_coaldf + Em_NGcombdf
#print(sfbasedf)
print(em_tot)
print(em_tot_dom)
width = 4.5
zeros = [0,0,0,0,0,0,0,0]

labels = np.arange(0, 80, 10)
fig = plt.figure(3,figsize=(10,6))
gs = fig.add_gridspec(1, 3, hspace=0.05, wspace=0.1)
(ax1, ax2, ax3) = gs.subplots(sharex='col', sharey='row')
ax1.bar(labels, Em_coaldf['Base'].to_list(), width =width, color = 'black')
ax2.bar(labels, Em_coaldf['Moderate'].to_list(), width =width, color = 'black')
ax3.bar(labels, Em_coaldf['Deep'].to_list(), width =width, color = 'black', label = 'Coal Emissions')
ax1.bar(labels, Em_oildf['Base'].to_list(), bottom=[*map(max,zip(zeros,Em_coaldf['Base'].to_list()))], width =width, color = 'brown')
ax2.bar(labels, Em_oildf['Moderate'].to_list(), bottom=[*map(max,zip(zeros,Em_coaldf['Moderate'].to_list()))],width =width, color = 'brown')
ax3.bar(labels, Em_oildf['Deep'].to_list(), bottom=[*map(max,zip(zeros,Em_coaldf['Deep'].to_list()))], width =width, color = 'brown', label = 'Oil Emissions')
ax1.bar(labels, Em_NGcombdf['Base'].to_list(),bottom=[*map(min,zip(zeros,Em_coaldf['Base'].to_list()))], width =width, color = 'purple')
ax2.bar(labels, Em_NGcombdf['Moderate'].to_list(), bottom=[*map(min,zip(zeros,Em_coaldf['Moderate'].to_list()))],width =width, color = 'purple')
ax3.bar(labels, Em_NGcombdf['Deep'].to_list(), bottom=[*map(min,zip(zeros,Em_coaldf['Deep'].to_list()))],width =width, color = 'purple', label = 'Gas Combustion Emissions')
ax1.bar(labels, Em_NGUpdf['Base'].to_list(), bottom = [*map(min,zip(Em_NGcombdf['Base'].to_list(),em_co_o['Base'].to_list()))], width =width, color = 'violet')
ax2.bar(labels, Em_NGUpdf['Moderate'].to_list(), bottom = [*map(min,zip(Em_NGcombdf['Moderate'].to_list(),em_co_o['Moderate'].to_list()))], width =width, color = 'violet')
ax3.bar(labels, Em_NGUpdf['Deep'].to_list(), bottom = [*map(min,zip(Em_NGcombdf['Deep'].to_list(),em_co_o['Deep'].to_list()))], width =width, color = 'violet', label = 'Upstream Gas Emissions')
ax1.plot(labels,em_tot['Base'],color='blue', marker = 'o', markersize = 8, linewidth = 3,label = 'Total Emissions')
ax2.plot(labels,em_tot['Moderate'],color='blue',marker = 'o', markersize = 8,linewidth = 3,label = 'Total Emissions')
ax3.plot(labels,em_tot['Deep'],color='blue', marker = 'o',markersize = 8,linewidth = 3,label = 'Total Emissions')
ax1.plot(labels,em_tot_dom['Base'],color='green', marker = 'o', markersize = 8, linewidth = 3,label = 'Territorial Emissions')
ax2.plot(labels,em_tot_dom['Moderate'],color='green',marker = 'o', markersize = 8,linewidth = 3,label = 'Territorial Emissions')
ax3.plot(labels,em_tot_dom['Deep'],color='green', marker = 'o',markersize = 8,linewidth = 3,label = 'Territorial Emissions')
ax1.plot(labels,sfbasedf['Base'],color='red', marker = 'o', markersize = 8, linewidth = 3,label = 'Total Shortfall')
ax2.plot(labels,sfbasedf['Moderate'],color='red',marker = 'o', markersize = 8,linewidth = 3,label = 'Total Shortfall')
ax3.plot(labels,sfbasedf['Deep'],color='red', marker = 'o',markersize = 8,linewidth = 3,label = 'Total Shortfall')
ax1.set_title('Baseline Demand Reduction', fontdict = {'fontsize':12})
ax2.set_title('Moderate Demand Reduction', fontdict = {'fontsize':12})
ax3.set_title('Deep Demand Reduction', fontdict = {'fontsize':12})
ax1.set_ylabel('Change in Emissions (MTCO2e/year - GWP-100) and Shortfall (bcm/yr)', fontsize=12)
ax2.set_xlabel('Reduction in Natural Gas Use for Electricity Generation (bcm/yr)', fontdict = {'fontsize':12})
ax1.set_xticks(labels)
ax2.set_xticks(labels)
ax3.set_xticks(labels)
ax3.legend(loc='lower center',bbox_to_anchor=(-0.6, -0.32), fontsize=12, ncol=3)

plt.savefig('Emissions.png', bbox_inches='tight', dpi = 150)
plt.show()
# Out:
#          Base  Baseline  Case        Deep    Moderate  Unnamed: 4  Unnamed: 5  \
# 0 -288.846400       NaN     0 -437.553820 -358.502553         NaN -424.086109
# 1 -243.103781       NaN    40 -402.879948 -321.333131         NaN -386.875016
# 2 -198.726934       NaN    80 -364.029122 -283.464233         NaN -348.849415
# 3 -162.877910       NaN   120 -324.194359 -238.999539         NaN -304.199209
# 4 -124.049511       NaN   160 -281.533831 -202.125957         NaN -267.464080
# 5  -85.037536       NaN   200 -253.285767 -163.030451         NaN -228.477001
# 6  -45.477284       NaN   240 -230.675918 -131.678950         NaN -196.001509
# 7  -13.081481       NaN   280 -206.423544 -106.262400         NaN -173.643766
#
#       Unnamed: 6
# 0 -184386.174798
# 1 -136274.390101
# 2  -87868.885704
# 3  -39516.175145
# 4    8650.875075
# 5   57079.158083
# 6  107076.896537
# 7  156446.311933
#          Base  Baseline  Case        Deep    Moderate  Unnamed: 4  Unnamed: 5  \
# ...

# %%
Em_coaldf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsCoalComb.csv", header = 'infer', sep = ',')
Em_oildf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsOilComb.csv", header = 'infer', sep = ',')
Em_NGcombdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsNGCombJune.csv", header = 'infer', sep = ',')
Em_NGUpdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsNGUpstreamJune.csv", header = 'infer', sep = ',')
sfbasedf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot1ShortfallJune.csv", header = 'infer', sep = ',')
em_tot = Em_NGcombdf + Em_NGUpdf + Em_coaldf + Em_oildf
em_tot_dom = Em_NGcombdf + Em_coaldf + Em_oildf
em_co_o = Em_coaldf + Em_NGcombdf
#print(sfbasedf)
print(em_tot)
print(em_tot_dom)
width = 4.5
zeros = [0,0,0,0,0,0,0,0]

labels = np.arange(0, 80, 10)
fig = plt.figure(3,figsize=(10,6))
gs = fig.add_gridspec(1, 3, hspace=0.05, wspace=0.1)
(ax1, ax2, ax3) = gs.subplots(sharex='col', sharey='row')
ax1.bar(labels, Em_coaldf['Base'].to_list(), width =width, color = 'black')
ax2.bar(labels, Em_coaldf['Moderate'].to_list(), width =width, color = 'black')
ax3.bar(labels, Em_coaldf['Deep'].to_list(), width =width, color = 'black', label = 'Coal Emissions')
ax1.bar(labels, Em_oildf['Base'].to_list(), bottom=[*map(max,zip(zeros,Em_coaldf['Base'].to_list()))], width =width, color = 'brown')
ax2.bar(labels, Em_oildf['Moderate'].to_list(), bottom=[*map(max,zip(zeros,Em_coaldf['Moderate'].to_list()))],width =width, color = 'brown')
ax3.bar(labels, Em_oildf['Deep'].to_list(), bottom=[*map(max,zip(zeros,Em_coaldf['Deep'].to_list()))], width =width, color = 'brown', label = 'Oil Emissions')
ax1.bar(labels, Em_NGcombdf['Base'].to_list(),bottom=[*map(min,zip(zeros,Em_coaldf['Base'].to_list()))], width =width, color = 'purple')
ax2.bar(labels, Em_NGcombdf['Moderate'].to_list(), bottom=[*map(min,zip(zeros,Em_coaldf['Moderate'].to_list()))],width =width, color = 'purple')
ax3.bar(labels, Em_NGcombdf['Deep'].to_list(), bottom=[*map(min,zip(zeros,Em_coaldf['Deep'].to_list()))],width =width, color = 'purple', label = 'Gas Combustion Emissions')
ax1.bar(labels, Em_NGUpdf['Base'].to_list(), bottom = [*map(min,zip(Em_NGcombdf['Base'].to_list(),em_co_o['Base'].to_list()))], width =width, color = 'violet')
ax2.bar(labels, Em_NGUpdf['Moderate'].to_list(), bottom = [*map(min,zip(Em_NGcombdf['Moderate'].to_list(),em_co_o['Moderate'].to_list()))], width =width, color = 'violet')
ax3.bar(labels, Em_NGUpdf['Deep'].to_list(), bottom = [*map(min,zip(Em_NGcombdf['Deep'].to_list(),em_co_o['Deep'].to_list()))], width =width, color = 'violet', label = 'Upstream Gas Emissions')
ax1.plot(labels,em_tot['Base'],color='blue', marker = 'o', markersize = 8, linewidth = 3,label = 'Total Emissions')
ax2.plot(labels,em_tot['Moderate'],color='blue',marker = 'o', markersize = 8,linewidth = 3,label = 'Total Emissions')
ax3.plot(labels,em_tot['Deep'],color='blue', marker = 'o',markersize = 8,linewidth = 3,label = 'Total Emissions')
ax1.plot(labels,em_tot_dom['Base'],color='green', marker = 'o', markersize = 8, linewidth = 3,label = 'Territorial Emissions')
ax2.plot(labels,em_tot_dom['Moderate'],color='green',marker = 'o', markersize = 8,linewidth = 3,label = 'Territorial Emissions')
ax3.plot(labels,em_tot_dom['Deep'],color='green', marker = 'o',markersize = 8,linewidth = 3,label = 'Territorial Emissions')
ax1.plot(labels,sfbasedf['Base'],color='red', marker = 'o', markersize = 8, linewidth = 3,label = 'Total Shortfall')
ax2.plot(labels,sfbasedf['Moderate'],color='red',marker = 'o', markersize = 8,linewidth = 3,label = 'Total Shortfall')
ax3.plot(labels,sfbasedf['Deep'],color='red', marker = 'o',markersize = 8,linewidth = 3,label = 'Total Shortfall')
ax1.set_title('Baseline Demand Reduction', fontdict = {'fontsize':12})
ax2.set_title('Moderate Demand Reduction', fontdict = {'fontsize':12})
ax3.set_title('Deep Demand Reduction', fontdict = {'fontsize':12})
ax1.set_ylabel('Change in Emissions (MTCO2e/year - GWP-100) and Shortfall (bcm/yr)', fontsize=12)
ax2.set_xlabel('Reduction in Natural Gas Use for Electricity Generation (bcm/yr)', fontdict = {'fontsize':12})
ax1.set_xticks(labels)
ax2.set_xticks(labels)
ax3.set_xticks(labels)
ax3.legend(loc='lower center',bbox_to_anchor=(-0.6, -0.32), fontsize=12, ncol=3)

plt.savefig('EmissionsJune.png', bbox_inches='tight', dpi = 150)
plt.show()
# Out:
#          Base  Baseline  Case        Deep    Moderate  Unnamed: 4  Unnamed: 5  \
# 0 -286.670148       NaN     0 -441.404734 -364.345894         NaN -441.334654
# 1 -248.034504       NaN    40 -407.723936 -326.803691         NaN -407.654276
# 2 -203.843993       NaN    80 -368.980223 -287.413902         NaN -368.903673
# 3 -168.096381       NaN   120 -328.022603 -242.267764         NaN -327.944748
# 4 -129.265663       NaN   160 -285.203338 -203.126486         NaN -285.127403
# 5  -87.046854       NaN   200 -250.869141 -164.972020         NaN -250.795093
# 6  -46.438231       NaN   240 -228.530369 -127.064648         NaN -227.469630
# 7   -6.966591       NaN   280 -204.434235 -102.573720         NaN -203.945619
#
#       Unnamed: 6
# 0 -184420.671887
# 1 -136315.948621
# 2  -87908.994220
# 3  -39563.666221
# 4    8615.548430
# 5   57034.521898
# 6  107013.960296
# 7  156385.708226
#          Base  Baseline  Case        Deep    Moderate  Unnamed: 4  Unnamed: 5  \
# ...

# %%
Em_coaldf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsCoalComb.csv", header = 'infer', sep = ',')
Em_oildf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsOilComb.csv", header = 'infer', sep = ',')
Em_NGcombdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsNGCombOct.csv", header = 'infer', sep = ',')
Em_NGUpdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsNGUpstreamOct.csv", header = 'infer', sep = ',')
sfbasedf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot1ShortfallOct.csv", header = 'infer', sep = ',')
em_tot = Em_NGcombdf + Em_NGUpdf + Em_coaldf + Em_oildf
em_tot_dom = Em_NGcombdf + Em_coaldf + Em_oildf
em_co_o = Em_coaldf + Em_NGcombdf
#print(sfbasedf)
print(em_tot)
print(em_tot_dom)
width = 4.5
zeros = [0,0,0,0,0,0,0,0]

labels = np.arange(0, 80, 10)
fig = plt.figure(3,figsize=(10,6))
gs = fig.add_gridspec(1, 3, hspace=0.05, wspace=0.1)
(ax1, ax2, ax3) = gs.subplots(sharex='col', sharey='row')
ax1.bar(labels, Em_coaldf['Base'].to_list(), width =width, color = 'black')
ax2.bar(labels, Em_coaldf['Moderate'].to_list(), width =width, color = 'black')
ax3.bar(labels, Em_coaldf['Deep'].to_list(), width =width, color = 'black', label = 'Coal Emissions')
ax1.bar(labels, Em_oildf['Base'].to_list(), bottom=[*map(max,zip(zeros,Em_coaldf['Base'].to_list()))], width =width, color = 'brown')
ax2.bar(labels, Em_oildf['Moderate'].to_list(), bottom=[*map(max,zip(zeros,Em_coaldf['Moderate'].to_list()))],width =width, color = 'brown')
ax3.bar(labels, Em_oildf['Deep'].to_list(), bottom=[*map(max,zip(zeros,Em_coaldf['Deep'].to_list()))], width =width, color = 'brown', label = 'Oil Emissions')
ax1.bar(labels, Em_NGcombdf['Base'].to_list(),bottom=[*map(min,zip(zeros,Em_coaldf['Base'].to_list()))], width =width, color = 'purple')
ax2.bar(labels, Em_NGcombdf['Moderate'].to_list(), bottom=[*map(min,zip(zeros,Em_coaldf['Moderate'].to_list()))],width =width, color = 'purple')
ax3.bar(labels, Em_NGcombdf['Deep'].to_list(), bottom=[*map(min,zip(zeros,Em_coaldf['Deep'].to_list()))],width =width, color = 'purple', label = 'Gas Combustion Emissions')
ax1.bar(labels, Em_NGUpdf['Base'].to_list(), bottom = [*map(min,zip(Em_NGcombdf['Base'].to_list(),em_co_o['Base'].to_list()))], width =width, color = 'violet')
ax2.bar(labels, Em_NGUpdf['Moderate'].to_list(), bottom = [*map(min,zip(Em_NGcombdf['Moderate'].to_list(),em_co_o['Moderate'].to_list()))], width =width, color = 'violet')
ax3.bar(labels, Em_NGUpdf['Deep'].to_list(), bottom = [*map(min,zip(Em_NGcombdf['Deep'].to_list(),em_co_o['Deep'].to_list()))], width =width, color = 'violet', label = 'Upstream Gas Emissions')
ax1.plot(labels,em_tot['Base'],color='blue', marker = 'o', markersize = 8, linewidth = 3,label = 'Total Emissions')
ax2.plot(labels,em_tot['Moderate'],color='blue',marker = 'o', markersize = 8,linewidth = 3,label = 'Total Emissions')
ax3.plot(labels,em_tot['Deep'],color='blue', marker = 'o',markersize = 8,linewidth = 3,label = 'Total Emissions')
ax1.plot(labels,em_tot_dom['Base'],color='green', marker = 'o', markersize = 8, linewidth = 3,label = 'Territorial Emissions')
ax2.plot(labels,em_tot_dom['Moderate'],color='green',marker = 'o', markersize = 8,linewidth = 3,label = 'Territorial Emissions')
ax3.plot(labels,em_tot_dom['Deep'],color='green', marker = 'o',markersize = 8,linewidth = 3,label = 'Territorial Emissions')
ax1.plot(labels,sfbasedf['Base'],color='red', marker = 'o', markersize = 8, linewidth = 3,label = 'Total Shortfall')
ax2.plot(labels,sfbasedf['Moderate'],color='red',marker = 'o', markersize = 8,linewidth = 3,label = 'Total Shortfall')
ax3.plot(labels,sfbasedf['Deep'],color='red', marker = 'o',markersize = 8,linewidth = 3,label = 'Total Shortfall')
ax1.set_title('Baseline Demand Reduction', fontdict = {'fontsize':12})
ax2.set_title('Moderate Demand Reduction', fontdict = {'fontsize':12})
ax3.set_title('Deep Demand Reduction', fontdict = {'fontsize':12})
ax1.set_ylabel('Change in Emissions (MTCO2e/year - GWP-100) and Shortfall (bcm/yr)', fontsize=12)
ax2.set_xlabel('Reduction in Natural Gas Use for Electricity Generation (bcm/yr)', fontdict = {'fontsize':12})
ax1.set_xticks(labels)
ax2.set_xticks(labels)
ax3.set_xticks(labels)
ax3.legend(loc='lower center',bbox_to_anchor=(-0.6, -0.32), fontsize=12, ncol=3)

plt.savefig('EmissionsOct.png', bbox_inches='tight', dpi = 150)
plt.show()
# Out:
#          Base  Baseline  Case        Deep    Moderate  Unnamed: 4  Unnamed: 5  \
# 0 -262.288875       NaN     0 -416.477196 -337.120359         NaN -416.407116
# 1 -222.898571       NaN    40 -377.364512 -301.872826         NaN -377.294852
# 2 -181.756179       NaN    80 -339.536077 -261.563315         NaN -339.459526
# 3 -142.470272       NaN   120 -298.769170 -219.042386         NaN -298.691314
# 4  -99.752580       NaN   160 -262.405215 -178.838490         NaN -262.329281
# 5  -63.574910       NaN   200 -239.310593 -144.002337         NaN -239.236545
# 6  -32.645796       NaN   240 -213.684335 -121.558561         NaN -212.623596
# 7  -11.770089       NaN   280 -190.472437 -100.899486         NaN -189.983821
#
#       Unnamed: 6
# 0 -184393.225083
# 1 -136277.638043
# 2  -87872.514197
# 3  -39527.567625
# 4    8638.736405
# 5   57035.230726
# 6  107021.244094
# 7  156391.223553
#          Base  Baseline  Case        Deep    Moderate  Unnamed: 4  Unnamed: 5  \
# ...

# %%
Em_coaldf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsCoalComb.csv", header = 'infer', sep = ',')
Em_oildf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsOilComb.csv", header = 'infer', sep = ',')
Em_NGcombdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsNGCombOct.csv", header = 'infer', sep = ',')
Em_NGUpdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot5EmissionsNGUpstreamOct.csv", header = 'infer', sep = ',')
sfbasedf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot1ShortfallBase.csv", header = 'infer', sep = ',')
em_tot = Em_NGcombdf + Em_NGUpdf + Em_coaldf + Em_oildf
em_tot_dom = Em_NGcombdf + Em_coaldf + Em_oildf
print(sfbasedf)
print(em_tot)
print(em_tot_dom)


labels = np.arange(0, 80, 10)
fig = plt.figure(3,figsize=(10,6))
gs = fig.add_gridspec(1, 4, hspace=0.05, wspace=0.1)
(ax1, ax2, ax3, ax4) = gs.subplots(sharex='col', sharey='row')
ax1.bar(labels, Em_coaldf['None'].to_list(), width = 7, color = 'black')
ax2.bar(labels, Em_coaldf['Base'].to_list(), width = 7, color = 'black')
ax3.bar(labels, Em_coaldf['Moderate'].to_list(), width = 7, color = 'black')
ax4.bar(labels, Em_coaldf['Deep'].to_list(), width = 7, color = 'black', label = 'Coal Emissions')
ax1.bar(labels, Em_oildf['None'].to_list(), bottom=Em_coaldf['None'].to_list(), width = 7, color = 'brown')
ax2.bar(labels, Em_oildf['Base'].to_list(), bottom=Em_coaldf['Base'].to_list(),width = 7, color = 'brown')
ax3.bar(labels, Em_oildf['Base'].to_list(), bottom=Em_coaldf['Base'].to_list(),width = 7, color = 'brown')
ax4.bar(labels, Em_oildf['Deep'].to_list(), bottom=Em_coaldf['Deep'].to_list(), width = 7, color = 'brown', label = 'Oil Emissions')
ax1.bar(labels, Em_NGcombdf['Base'].to_list(), width = 7, color = 'purple')
ax2.bar(labels, Em_NGcombdf['Moderate'].to_list(), width = 7, color = 'purple')
ax3.bar(labels, Em_NGcombdf['Deep'].to_list(), width = 7, color = 'purple', label = 'Gas Combustion Emissions')
ax1.bar(labels, Em_NGUpdf['Base'].to_list(), bottom = Em_NGcombdf['None'].to_list(), width = 7, color = 'violet')
ax2.bar(labels, Em_NGUpdf['Moderate'].to_list(), bottom = Em_NGcombdf['Base'].to_list(), width = 7, color = 'violet')
ax3.bar(labels, Em_NGUpdf['Deep'].to_list(), bottom = Em_NGcombdf['Deep'].to_list(), width = 7, color = 'violet', label = 'Upstream Gas Emissions')
ax1.plot(labels,em_tot['Base'],color='blue', marker = 'o', markersize = 8, linewidth = 3,label = 'Total Emissions')
ax2.plot(labels,em_tot['Moderate'],color='blue',marker = 'o', markersize = 8,linewidth = 3,label = 'Total Emissions')
ax3.plot(labels,em_tot['Deep'],color='blue', marker = 'o',markersize = 8,linewidth = 3,label = 'Total Emissions')
ax1.plot(labels,sfbasedf['Base'],color='red', marker = 'o', markersize = 8, linewidth = 3,label = 'Total Shortfall')
ax2.plot(labels,sfbasedf['Moderate'],color='red',marker = 'o', markersize = 8,linewidth = 3,label = 'Total Shortfall')
ax3.plot(labels,sfbasedf['Deep'],color='red', marker = 'o',markersize = 8,linewidth = 3,label = 'Total Shortfall')
ax1.set_title('Baseline Demand Reduction', fontdict = {'fontsize':12})
ax2.set_title('Moderate Demand Reduction', fontdict = {'fontsize':12})
ax3.set_title('Deep Demand Reduction', fontdict = {'fontsize':12})
ax1.set_ylabel('Change in Emissions (MTCO2e/year) and Shortfall (bcm/yr)', fontsize=12)
ax2.set_xlabel('Reduction in Natural Gas Use for Electricity Generation (bcm/yr)', fontdict = {'fontsize':12})
ax1.set_xticks(labels)
ax2.set_xticks(labels)
ax3.set_xticks(labels)
ax3.legend(loc='lower center',bbox_to_anchor=(-0.6, -0.25), fontsize=12, ncol=3)

plt.savefig('Emissions.png', bbox_inches='tight', dpi = 150)
plt.show()
# Out:
#    Case       Base   Moderate       Deep  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0     0  39.310701  31.989988  25.020016         NaN   39.310701   78.621401
# 1    10  31.385460  27.222997  20.867544         NaN   31.385460   62.770920
# 2    20  23.062844  21.818510  16.067520         NaN   23.062844   46.125687
# 3    30  17.986900  13.487317   9.845101         NaN   17.986900   35.973800
# 4    40  12.384135   8.377025   2.295376         NaN   12.384135   24.768270
# 5    50   7.279736   2.776581   0.162222         NaN    7.279736   14.559473
# 6    60   2.118324   0.196225   0.162222         NaN    2.118324    4.236648
# 7    70   0.226238   0.195512   0.162222         NaN    0.226238    0.452477
#          Base  Baseline  Case        Deep    Moderate  Unnamed: 4  Unnamed: 5  \
# 0 -253.092146       NaN     0 -410.340577 -329.518612         NaN -395.102168
# 1 -213.997801       NaN    40 -375.621548 -292.297857         NaN -357.839742
# ...

# %%
Sumdf = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot6Pies.csv", header = 'infer', sep = ',')
fig = make_subplots(rows=2, cols=3, subplot_titles=("Base - 70 bcm", "Moderate - 60 bcm", "Deep - 50 bcm", "Deep, Low LNG - 70 bcm", "Deep, High LNG - 70 bcm", "Deep, Balanced LNG - 50 bcm"))
fig1 = fig.add_trace(go.Waterfall(
    orientation = "v",
    x = ["RU", "Elec", "CHP", "Ind", "Res", "Comm", "Pipe", "LNG", "Storage", "Short", "Mismatch"],
    measure =["absolute", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative","relative","total"],
    y = Sumdf['Base70plot'].to_list(), base = 0,
    decreasing = {"marker":{"color":"green", "line":{"color":"darkturquoise", "width":1}}},
    totals = {"marker":{"color":"maroon", "line":{"color":"red", "width":1}}}
),row=1, col=1)
fig.update_traces(textangle=-45, selector=dict(type='waterfall'))
fig1.update_layout(waterfallgap = 0.2)
fig2 = fig.add_trace(go.Waterfall(
    orientation = "v",
    x = ["RU", "Elec", "CHP", "Ind", "Res", "Comm", "Pipe", "LNG", "Storage", "Short", "Mismatch"],
    measure =["absolute", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative","relative","total"],
    y = Sumdf['Moderate60'].to_list(), base = 0,
    decreasing = {"marker":{"color":"green", "line":{"color":"darkturquoise", "width":1}}},
    totals = {"marker":{"color":"maroon", "line":{"color":"red", "width":1}}}
),row=1, col=2)
fig.update_traces(textangle=-45, selector=dict(type='waterfall'))
fig2.update_layout(waterfallgap = 0.2)
fig3 = fig.add_trace(go.Waterfall(
    orientation = "v",
    x = ["RU", "Elec", "CHP", "Ind", "Res", "Comm", "Pipe", "LNG", "Storage", "Short", "Mismatch"],
    measure =["absolute", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative","relative","total"],
    y = Sumdf['Deep50'].to_list(), base = 0,
    decreasing = {"marker":{"color":"green", "line":{"color":"darkturquoise", "width":1}}},
    totals = {"marker":{"color":"maroon", "line":{"color":"red", "width":1}}}
),row=1, col=3)
fig.update_traces(textangle=-45, selector=dict(type='waterfall'))
fig3.update_layout(waterfallgap = 0.2)
fig4 = fig.add_trace(go.Waterfall(
    orientation = "v",
    x = ["RU", "Elec", "CHP", "Ind", "Res", "Comm", "Pipe", "LNG", "Storage", "Short", "Mismatch"],
    measure =["absolute", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative","relative","total"],
    y = Sumdf['Deep70'].to_list(), base = 0,
    decreasing = {"marker":{"color":"green", "line":{"color":"darkturquoise", "width":1}}},
    totals = {"marker":{"color":"maroon", "line":{"color":"red", "width":1}}}
),row=2, col=1)
fig.update_traces(textangle=-45, selector=dict(type='waterfall'))
fig4.update_layout(waterfallgap = 0.2)
fig5 = fig.add_trace(go.Waterfall(
    orientation = "v",
    x = ["RU", "Elec", "CHP", "Ind", "Res", "Comm", "Pipe", "LNG", "Storage", "Short", "Mismatch"],
    measure =["absolute", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative","relative","total"],
    y = Sumdf['Deep70LNG'].to_list(), base = 0,
    increasing = {"marker":{"color":"dodgerblue", "line":{"color":"deep sky blue", "width":1}}},
    decreasing = {"marker":{"color":"green", "line":{"color":"darkturquoise", "width":1}}},
    totals = {"marker":{"color":"maroon", "line":{"color":"red", "width":1}}}
),row=2, col=2)
fig5.update_layout(waterfallgap = 0.2)
fig6 = fig.add_trace(go.Waterfall(
    orientation = "v",
    x = ["RU", "Elec", "CHP", "Ind", "Res", "Comm", "Pipe", "LNG", "Storage", "Short", "Mismatch"],
    measure =["absolute", "relative", "relative", "relative", "relative", "relative", "relative", "relative", "relative","relative","total"],
    y = Sumdf['Deep70Mix'].to_list(), base = 0,
    decreasing = {"marker":{"color":"green", "line":{"color":"darkturquoise", "width":1}}},
    totals = {"marker":{"color":"maroon", "line":{"color":"red", "width":1}}}
),row=2, col=3)
fig5.update_layout(waterfallgap = 0.2)
fig.update_traces(textangle=45, selector=dict(type='waterfall'))
fig.update_layout(
    margin=dict(l=40, r=40, t=40, b=40),
    paper_bgcolor="white",
    showlegend=False,
    plot_bgcolor="white",
    font_size = 15,
    grid_xgap=0.01,
    grid_ygap=0.01
)
fig.update_xaxes(linecolor="black")
fig.update_xaxes(title_text="Sectoral Contributions", row=2, col=2, title_standoff=2)
fig.update_yaxes(title_text="bcm/yr", row=1,col=1, title_standoff=2)
fig.update_yaxes(title_text="bcm/yr", row=2,col=1, title_standoff=2)
fig.update_yaxes(linecolor="black")
fig.update_annotations(font_size=20)
fig.write_image("waterfall.png", width=1200, height=700, scale=4)
fig.show()
# Out:
# <div>                            <div id="ff0035cc-f308-4244-8d27-1ab411d4b701" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff0035cc-f308-4244-8d27-1ab411d4b701")) {                    Plotly.newPlot(                        "ff0035cc-f308-4244-8d27-1ab411d4b701",                        [{"base":0,"decreasing":{"marker":{"color":"green","line":{"color":"darkturquoise","width":1}}},"measure":["absolute","relative","relative","relative","relative","relative","relative","relative","relative","relative","total"],"orientation":"v","totals":{"marker":{"color":"maroon","line":{"color":"red","width":1}}},"x":["RU","Elec","CHP","Ind","Res","Comm","Pipe","LNG","Storage","Short","Mismatch"],"y":[136.5722115,-68.44883267,-2.96,-0.77,-3.6,-1.814623825,-3.5374
# ...

# %%
leg = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Plot6Legend.csv", header = 'infer', sep = ',')
fig = plt.figure(4,figsize=(14,6))
gs = fig.add_gridspec(1, 1, hspace=0.05, wspace=0.1)
(ax1) = gs.subplots(sharex='col', sharey='row')
labels = 10
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#990000', label='Russian Gas to Substitute')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#ED7D31', label='Russian LNG to Substitute')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#FF0000', label='Russian Gas Prior to Oct. 2022')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#7030A0', label='LNG Imports')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#00B0F0', label='Alternative Pipelines')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#228B22', label='Biogas')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#FFC000', label='Electricity Sector Gas Reduction')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#C55A11', label='Demand Reduction: CHP')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#0070C0', label='Demand Reduction: Industry')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#6699FF', label='Demand Reduction: Residential')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#92D050', label='Demand Reduction: Commercial')
ax1.bar(labels, leg['Ru'].to_list(), width = 7, color = '#7F7F7F', label='Increased Storage Volumes vs Apr. 2022')
ax1.legend(loc='lower center', fontsize=12,bbox_to_anchor=(0.5,-.4), ncol=3)
plt.savefig('Legend.png', bbox_inches='tight', dpi = 150)
plt.show()

# %%
Ems2022 = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\EmissionsPlot2022.csv", header = 'infer', sep = ',')
Ems2023 = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\EmissionsPlot2023.csv", header = 'infer', sep = ',')
zeros2 = [0,0]
Ems2023neg = np.minimum(zeros2,Ems2023['Coal'])
print(Ems2023neg.to_list())
Ems2023neg = Ems2023neg + Ems2023['Gas'] + Ems2023['Oil']

width = 0.6
zeros = [0,0,0,0,0,0,0,0]
labels = ['Core Scenario', 'Low Demand Reduction']
fig = plt.figure(3,figsize=(10,6))
gs = fig.add_gridspec(1, 2, hspace=0.1, wspace=0.1)
(ax1, ax2) = gs.subplots(sharex='col', sharey='row')
ax1.bar(labels, Ems2022['Coal'].to_list(), width =width, color = 'black', label = 'Coal')
ax2.bar(labels, Ems2023['Coal'].to_list(), width =width, color = 'black', label = 'Coal')
ax1.bar(labels, Ems2022['Oil'].to_list(), bottom=[*map(max,zip(zeros,Ems2022['Coal'].to_list()))], width =width, color = 'brown', label = 'Oil')
ax2.bar(labels, Ems2023['Oil'].to_list(), bottom=[*map(min,zip(zeros,Ems2023['Coal'].to_list()))], width =width, color = 'brown', label = 'Oil')
ax1.bar(labels, Ems2022['Gas'].to_list(), width =width, bottom=[*map(min,zip(zeros,Ems2022['Coal'].to_list()))], color = 'purple', label = 'Gas Demand Reduction')
ax2.bar(labels, Ems2023['Gas'].to_list(), width =width, bottom=[*map(min,zip(Ems2023['Coal'].to_list(), Ems2023['Oil'].to_list()))], color = 'purple', label = 'Gas Demand Reduction')
ax1.bar(labels, Ems2022['Upstream'].to_list(), width =width, bottom = [*map(min,zip(zeros,Ems2022['Coal'].to_list(),Ems2022['Oil'].to_list(),Ems2022['Gas'].to_list()))], color = 'violet', edgecolor = 'red', label = 'Gas, Out-of-Territory', alpha = 0.3)
ax2.bar(labels, Ems2023['Upstream'].to_list(), width =width, bottom = [*map(min,zip(Ems2023neg.to_list()))],color = 'violet',edgecolor = 'red', label = 'Gas, Out-of-Territory', alpha = 0.3)
ax1.bar(labels, Ems2022['LNG'].to_list(), width =width, bottom = [*map(min,zip(Ems2022['Coal'].to_list(),Ems2022['Oil'].to_list(),Ems2022['Upstream'].to_list(),Ems2022['Gas'].to_list())),] , color='none', edgecolor = 'gold', label = 'Gas, Out-of-Territory: LNG', alpha = 1)
ax2.bar(labels, Ems2023['LNG'].to_list(), width =width, bottom =[*map(min,zip(Ems2023neg.to_list()))],color='none',  edgecolor = 'gold', label = 'Gas, Out-of-Territory: LNG', alpha = 1)
ax1.bar(labels, Ems2022['Russia'].to_list(), width =width, bottom = [*map(min,zip(Ems2022['Coal'].to_list(),Ems2022['Gas'].to_list(),Ems2022['Upstream'].to_list()))], color='none', edgecolor = 'red', label = 'Gas, Out-of-Territory: Russia', alpha = 1)
ax2.bar(labels, Ems2023['Russia'].to_list(), width =width, bottom = [*map(min,zip(Ems2023neg.to_list()))],color='none',  edgecolor = 'red', label = 'Gas, Out-of-Territory: Russia', alpha = 1)
ax1.plot(labels,Ems2022['Total'],color='red', marker = "o", markersize = 8, linewidth = 0, label = 'Total Emissions Reductions')
ax2.plot(labels,Ems2023['Total'],color='red', marker = "o", markersize = 8, linewidth = 0,label = 'Total Emissions Reductions')
ax1.plot(labels,Ems2022['TotalIn'],color='turquoise', marker = "o", markersize = 8, linewidth = 0,label = 'In-Territory Emissions Reductions')
ax2.plot(labels,Ems2023['TotalIn'],color='turquoise', marker = "o", markersize = 8, linewidth = 0,label = 'In-Territory Emissions Reductions')
ax1.set_title('Change in Emissions 2022-2023', fontdict = {'fontsize':14})
ax2.set_title('Change in Emissions 2023-2024', fontdict = {'fontsize':14})
ax1.set_ylabel('Mt CO2e/year - GWP-100', fontsize=12)
ax1.set_xlabel('Case', fontdict = {'fontsize':12})
ax2.set_xlabel('Case', fontdict = {'fontsize':12})
ax1.set_xticks(labels, fontdict = {'fontsize':14})
ax2.set_xticks(labels, fontdict = {'fontsize':14})
ax2.legend(loc='lower center',bbox_to_anchor=(-0.06, -0.33), fontsize=12, ncol=3)

plt.savefig('EmissionsOct.png', bbox_inches='tight', dpi = 150)
plt.show()
# Out:
# [-52.01892711, 0.0]

# %%
Ems2022memo = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Ems2022Memo.csv", header = 'infer', sep = ',')
Ems2023memo = pd.read_csv("C:\\Users\\mike_\\OneDrive\\Documents\\PhD\\ZERO_Lab\\Russian_Gas\\Plotting\\Ems2023Memo.csv", header = 'infer', sep = ',')
zeros3 = [0,0,0]
Ems2023negmemo = np.minimum(zeros3,Ems2023memo['Coal'])
print(Ems2023negmemo.to_list())
Ems2023negmemo = Ems2023negmemo + Ems2023memo['Gas'] + Ems2023memo['Oil']

width = 0.6
labels = ['High Coal', 'Balanced', 'Accelerated RE']
fig = plt.figure(4,figsize=(10,6))
gs = fig.add_gridspec(1, 2, hspace=0.1, wspace=0.1)
(ax1, ax2) = gs.subplots(sharex='col', sharey='row')
ax1.bar(labels, Ems2022memo['Coal'].to_list(), width =width, color = 'black', label = 'Coal')
ax2.bar(labels, Ems2023memo['Coal'].to_list(), width =width, color = 'black', label = 'Coal')
ax1.bar(labels, Ems2022memo['Oil'].to_list(), bottom=[*map(max,zip(zeros3,Ems2022memo['Coal'].to_list()))], width =width, color = 'brown', label = 'Oil')
ax2.bar(labels, Ems2023memo['Oil'].to_list(), bottom=[*map(min,zip(zeros3,Ems2023memo['Coal'].to_list()))], width =width, color = 'brown', label = 'Oil')
ax1.bar(labels, Ems2022memo['Gas'].to_list(), width =width, bottom=[*map(min,zip(zeros3,Ems2022memo['Coal'].to_list()))], color = 'purple', label = 'Gas Demand Reduction')
ax2.bar(labels, Ems2023memo['Gas'].to_list(), width =width, bottom=[*map(min,zip(Ems2023memo['Coal'].to_list(), Ems2023memo['Oil'].to_list()))], color = 'purple', label = 'Gas Demand Reduction')
ax1.bar(labels, Ems2022memo['Upstream'].to_list(), width =width, bottom = [*map(min,zip(zeros3,Ems2022memo['Coal'].to_list(),Ems2022memo['Oil'].to_list(),Ems2022memo['Gas'].to_list()))], color = 'violet', edgecolor = 'red', label = 'Gas, Out-of-Territory', alpha = 0.3)
ax2.bar(labels, Ems2023memo['Upstream'].to_list(), width =width, bottom = [*map(min,zip(Ems2023negmemo.to_list()))],color = 'violet',edgecolor = 'red', label = 'Gas, Out-of-Territory', alpha = 0.3)
ax1.bar(labels, Ems2022memo['LNG'].to_list(), width =width, bottom = [*map(min,zip(Ems2022memo['Coal'].to_list(),Ems2022memo['Oil'].to_list(),Ems2022memo['Upstream'].to_list(),Ems2022memo['Gas'].to_list())),] , color='none', edgecolor = 'gold', label = 'Gas, Out-of-Territory: LNG', alpha = 1)
ax2.bar(labels, Ems2023memo['LNG'].to_list(), width =width, bottom =[*map(min,zip(Ems2023negmemo.to_list()))],color='none',  edgecolor = 'gold', label = 'Gas, Out-of-Territory: LNG', alpha = 1)
ax1.bar(labels, Ems2022memo['Russia'].to_list(), width =width, bottom = [*map(min,zip(Ems2022memo['Coal'].to_list(),Ems2022memo['Gas'].to_list(),Ems2022memo['Upstream'].to_list()))], color='none', edgecolor = 'red', label = 'Gas, Out-of-Territory: Russia', alpha = 1)
ax2.bar(labels, Ems2023memo['Russia'].to_list(), width =width, bottom = [*map(min,zip(Ems2023negmemo.to_list()))],color='none',  edgecolor = 'red', label = 'Gas, Out-of-Territory: Russia', alpha = 1)
ax1.plot(labels,Ems2022memo['Total'],color='red', marker = "o", markersize = 8, linewidth = 0, label = 'Total Emissions Reductions')
ax2.plot(labels,Ems2023memo['Total'],color='red', marker = "o", markersize = 8, linewidth = 0,label = 'Total Emissions Reductions')
ax1.plot(labels,Ems2022memo['TotalIn'],color='turquoise', marker = "o", markersize = 8, linewidth = 0,label = 'In-Territory Emissions Reductions')
ax2.plot(labels,Ems2023memo['TotalIn'],color='turquoise', marker = "o", markersize = 8, linewidth = 0,label = 'In-Territory Emissions Reductions')
ax1.set_title('Change in Emissions 2022-2023', fontdict = {'fontsize':14})
ax2.set_title('Change in Emissions 2023-2024', fontdict = {'fontsize':14})
ax1.set_ylabel('Mt CO2e/year - GWP-100', fontsize=12)
ax1.set_xlabel('Case', fontdict = {'fontsize':12})
ax2.set_xlabel('Case', fontdict = {'fontsize':12})
ax1.set_xticks(labels, fontdict = {'fontsize':14})
ax2.set_xticks(labels, fontdict = {'fontsize':14})
ax2.legend(loc='lower center',bbox_to_anchor=(-0.06, -0.33), fontsize=12, ncol=3)

plt.savefig('EmissionsMemo.png', bbox_inches='tight', dpi = 150)
plt.show()
# Out:
# [0.0, 0.0, 0.0]
